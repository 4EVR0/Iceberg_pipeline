# %%
import sys
sys.path.insert(0, "/shared/adv/iceberg-pipeline")

from config.settings import Iceberg

catalog = Iceberg.get_catalog()
table = catalog.load_table("oliveyoung_db.oliveyoung_category_master")
df = table.scan().to_arrow().to_pandas()

df
# Out:
#        category_id main_category sub_category
# 0       스킨케어_스킨-토너          스킨케어        스킨/토너
# 1   스킨케어_에센스-세럼-앰플          스킨케어    에센스/세럼/앰플
# 2          스킨케어_크림          스킨케어           크림
# 3          스킨케어_로션          스킨케어           로션
# 4      스킨케어_미스트-오일          스킨케어       미스트/오일
# 5         마스크팩_시트팩          마스크팩          시트팩
# 6          마스크팩_패드          마스크팩           패드
# 7        마스크팩_페이셜팩          마스크팩         페이셜팩
# 8          마스크팩_코팩          마스크팩           코팩
# 9          마스크팩_패치          마스크팩           패치
# 10      클렌징_클렌징폼-젤           클렌징       클렌징폼/젤
# 11        클렌징_오일-밤           클렌징         오일/밤
# 12       클렌징_워터-밀크           클렌징        워터/밀크
# 13      클렌징_필링&스크럽           클렌징       필링&스크럽
# 14     더모코스메틱_스킨케어       더모 코스메틱         스킨케어
# 15     더모코스메틱_바디케어       더모 코스메틱         바디케어
# 16      더모코스메틱_클렌징       더모 코스메틱          클렌징
# 17      더모코스메틱_선케어       더모 코스메틱          선케어
# 18     더모코스메틱_마스크팩       더모 코스메틱         마스크팩
# 19       맨즈케어_스킨케어          맨즈케어         스킨케어
